# %% [markdown]
# # Keras
#
# * keras 는 딥러닝 모델를 만들고 학습하는 High-level API 이다.
#
# * 친숙하고 모듈로 만들어져있고, 확장하기 쉽다는 장점이 있다.

# %% [markdown]
# # Import tf.keras
#
# * tf.keras는

# %%
# !pip install -q pyyaml

# %%
import tensorflow as tf
from tensorflow.keras import layers

print(tf.VERSION)
print(tf.keras.__version__)
# Out:
# 1.12.0
# 2.1.6-tf

# %% [markdown]
# # Build a simple model

# %%
# Sequential model
